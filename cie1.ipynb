# %% [markdown]
# <a href="https://colab.research.google.com/github/harshamalipatil16/cie1/blob/main/cie1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/mtcars.csv')

auto_count = (df['am'] == 0).sum()
manual_count = (df['am'] == 1).sum()

plt.bar(['Automatic','Manual'],[auto_count, manual_count])
plt.title('Frequency of distribution of transmission type')
plt.xlabel('Transmission Type')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/mtcars.csv')
plt.boxplot(df['mpg'])
plt.title('the box plot mpg')
plt.xlabel('MPG')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/mtcars.csv')
X = df['wt']
y = df['mpg']
plt.scatter(df['wt'], df['mpg'])
plt.title('the relationship between weight and mileage')
plt.xlabel('weight')
plt.ylabel('mileage')
plt.show()
